# %% [markdown]
# <a href="https://colab.research.google.com/github/ontologist/2025ML/blob/main/ML2025Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Machine Learning Intro**
# This is for the Fall 2025 ML & Intelligence class

# %%
import requests
from bs4 import BeautifulSoup
import time # Import time for delays
import csv
import os # Import os for path joining

base_url = "https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/"
companies = []
num_pages_to_extract = 10 # Extracting 10 pages as requested

for page_num in range(1, num_pages_to_extract + 1):
    # Construct the URL for each page.
    # You'll need to inspect the website's pagination to determine the correct URL structure.
    # A common pattern is something like: base_url + "?page=" + str(page_num)
    # Replace this with the actual pagination parameter.
    # For this example, I'll assume the page parameter is 'page'
    page_url = f"{base_url}?page={page_num}"

    print(f"Fetching data from page {page_num}: {page_url}")

    try:
        response = requests.get(page_url)
        response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)
        soup = BeautifulSoup(response.content, 'html.parser')

        for company_card in soup.find_all(class_='tabJobOfferCard'):
            # Extract information here - this will depend on the specific structure
            # within the tabJobOfferCard div. You'll need to inspect the HTML
            # of the page to find the specific tags and classes for the company name, etc.
            # For now, let's just add a placeholder or the whole card's text
            companies.append([company_card.get_text(strip=True)]) # Store as a list for CSV writing

        # Add a small delay between requests to avoid overwhelming the server
        time.sleep(1)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page {page_num}: {e}")
        # Decide whether to continue or stop on error
        continue # Continue to the next page

# Now you have the data from all pages in the 'companies' list.
# You can process or store it as needed.
print(f"\nExtracted data from {len(companies)} company cards across {num_pages_to_extract} pages.")

# Define the path to save the CSV file in Google Drive
drive_path = "/content/drive/MyDrive/2025ML"
file_name = "extracted-companies.csv"
file_path = os.path.join(drive_path, file_name)

# Save the data to a CSV file
with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Company Data']) # Write a header row
    writer.writerows(companies) # Write the extracted company data

print(f"Data saved to {file_path}")

# Print a sample of the extracted data
for i, company in enumerate(companies[:10]): # Print the first 10
    print(f"Company {i+1}: {company[0]}") # Access the string inside the list
# Out:
# Fetching data from page 1: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=1
# Fetching data from page 2: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=2
# Fetching data from page 3: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=3
# Fetching data from page 4: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=4
# Fetching data from page 5: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=5
# Fetching data from page 6: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=6
# Fetching data from page 7: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=7
# Fetching data from page 8: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=8
# Fetching data from page 9: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=9
# Fetching data from page 10: https://baito.mynavi.jp/hyogo/area_28-300_28-302_28-303_28-315_28-296_28-298/?page=10
#
# Extracted data from 300 company cards across 10 pages.
# Data saved to /content/drive/MyDrive/2025ML/extracted-companies.csv
# Company 1: 閲覧済みホテル竹園芦屋【お歳暮のお届日のご案内】11/14～12/20の期間限定ド短期募集♪履歴書不要◎カンタン♪給与時給1200円～＋交通費雇用形態アルバイト・パートシフト週2日以上 1日4時間以上勤務地兵庫県 芦屋市時間帯朝、昼、夕方、夜アクセス芦屋駅徒歩1分面接地兵庫県 芦屋市ホテル竹園芦屋の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 2: 閲覧済みeashion大丸神戸店【販売スタッフ】旧居留地・大丸前駅≪時給1200円≫夕方以降大歓迎です！履歴書不要◎週2~給与時給1200円～+交通費支給雇用形態アルバイト・パートシフト週2日以上 1日3時間以上勤務地兵庫県 神戸市 中央区時間帯朝、昼、夕方、夜アクセス旧居留地・大丸前駅徒歩1分面接地兵庫県 神戸市 中央区本日、掲載終了カネ美食品株式会社の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 3: 閲覧済みナッシュ株式会社【1】　尼崎工場【お弁当工場の清掃】履歴書なし＆来社面接で初回のみQUOカード2千円！月15日勤務♪給与時給1200円＋交通費支給雇用形態アルバイト・パートシフト週3日以上 1日8時間以上勤務地兵庫県 尼崎市 JR尼崎駅周辺時間帯朝、昼、夕方アクセス尼崎駅徒歩12分面接地兵庫県 尼崎市 JR尼崎駅周辺あと3日ナッシュ株式会社の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 4: NEW閲覧済み株式会社エスウィル他の店舗【無印良品、有名アパレル商品の軽作業etc.】週1～や短期OK★週払いOK♪高時給1500円も！給与時給1300円～時給1500円雇用形態派遣社員シフト週1日 1日3時間以上勤務地兵庫県 神戸市 西区時間帯朝、昼、夕方、夜アクセス名谷駅面接地兵庫県 神戸市 中央区株式会社エスウィルの求人一覧を見るWebで応募する電話番号を表示保存する
# Company 5: NEW閲覧済み戦力エージェント株式会社（尼崎）他の店舗【Amazon商品の仕分け】<登録制>1２月中旬までの短期★高時給1600円~×日払い！来社不要◎給与時給1600～2125円 ※別途交通費支給雇用形態派遣社員シフト週1日以上勤務地兵庫県 尼崎市 JR尼崎駅周辺時間帯早朝、朝、昼、夕方、夜、夜勤アクセス尼崎駅面接地あと6日戦力エージェント株式会社　京阪支店の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 6: 閲覧済み株式会社神戸風月堂 西神工場【お菓子の検品・箱詰め】12月末までの短期！高時給1300円！送迎バス＆面接時にギフトあり給与時給1300円　+交通費雇用形態アルバイト・パートシフト週3日以上 1日4時間以上勤務地兵庫県 神戸市 西区時間帯朝、昼、夕方アクセス西神中央駅徒歩15分面接地兵庫県 神戸市 西区本日、掲載終了株式会社神戸風月堂 西神工場の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 7: 閲覧済みジパング警備保障株式会社 神戸支店 【神戸エリア】他の店舗【警備スタッフ】＼入社祝い金10万円／短期＆単発も◎働き方自由！スキルゼロでもOK★給与<昼勤>日給1万2000円～ <夜勤>日給1万4000円～雇用形態アルバイト・パートシフト週1日以上勤務地兵庫県 神戸市 中央区時間帯朝、昼、夕方、夜、夜勤アクセス神戸三宮駅面接地兵庫県 神戸市 中央区本日、掲載終了ジパング警備保障株式会社の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 8: 閲覧済み合同会社プロティクス他の店舗【イベント警備】登録制★採用強化!CM・ドラマ・映画撮影やマラソン大会などイベント多数給与時給1200～1500円　＋交通費雇用形態アルバイト・パートシフト週1日以上 1日3時間以上勤務地兵庫県 神戸市 中央区時間帯早朝、朝、昼、夕方、夜、夜勤アクセス三ノ宮駅面接地兵庫県 西宮市 その他西宮市あと1日合同会社プロティクスの求人一覧を見るWebで応募する電話番号を表示保存する
# Company 9: 閲覧済みカラオケまねきねこ　新長田店【カラオケスタッフ】オープニングスタッフ大募集☆週1日～◎オシャレ自由♪社割半額☆給与時給1160円～（深夜時給：1450円～）＋交通費規定支給雇用形態アルバイト・パートシフト週1日以上 1日1時間以上勤務地兵庫県 神戸市 長田区時間帯早朝、朝、昼、夕方、夜、夜勤アクセス新長田駅徒歩2分面接地兵庫県 神戸市 長田区急募あと3日株式会社コシダカ　営業統括本部　近畿第二営業部の求人一覧を見るWebで応募する電話番号を表示保存する
# Company 10: 閲覧済み株式会社ライズエース他の店舗【搬入スタッフ】スグ稼げる!!高日給&日払いバイト♪"月収約30万円以上"も◎≪短期OK給与日給1万3000円～2万1500円+ 交通費全額支給雇用形態アルバイト・パートシフト週2日以上勤務地兵庫県 神戸市 中央区時間帯朝、昼、夕方、夜、夜勤アクセス三ノ宮駅面接地兵庫県 西宮市 西宮駅周辺オンライン面接可あと2日株式会社ライズエースの求人一覧を見るWebで応募する電話番号を表示保存する

# %% [markdown]
# ## Strings

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# ## Numbers

# %% [markdown]
# ### Operation

# %%
2 + 2
# Out:
# 4

# %%
print("Hello world: I am ", 20)
# Out:
# Hello world: I am  20
